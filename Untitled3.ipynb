# %%
from video_processor import *

# %%
g,c,cg = full_video_file_procedure('Zlobin1.avi')
# Out:
# processing time
# 0:03:05.938635

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(cg)

# %%
240/50
# Out:
# 4.8

# %%
a=[2,3,4]

# %%
a[1:]
# Out:
# [3, 4]

# %%
a[:-1]
# Out:
# [2, 3]

# %%
cg1 = cg[2:]
cg2 = cg[:-2]
cg3 = np.double(cg2) + np.double(cg1)

# %%
plt.plot(-out[7000:8960])

# %%
14000/60
# Out:
# 233.33333333333334

# %%
a=[2,3,4]
b=a[1:]
c=a[:-1]
b+c
# Out:
# [3, 4, 2, 3]

# %%
print(type(cg))
# Out:
# <class 'list'>

# %%
from amp_processor import *

# %%
out = butter_bandpass_filter(cg, 0.2, 5, 240, order=4)

# %%
def butter_bandpass(lowcut, highcut, fs, order=3):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a


def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    zi = lfilter_zi(b, a)
    y, z = lfilter(b, a, data, zi=zi*data[0])
    return y

# %%
from SignalDrawing import *

# %%
full_d('Signals/Fomenko_1_27.04.19/Contact.txt')
