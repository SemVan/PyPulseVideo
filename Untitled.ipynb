# %%
import full_segmented_video_creator
# Out:
# ./Segmented/Signals/Andreeva_1_27.04.19
# 10
# 7
# 769
# 640
# 480
# 3
# [[329 390]
#  [329 377]
#  [336 377]
#  [336 390]]
# [[329 377]
#  [329 373]
#  [336 373]
#  [336 377]]
# [[329 373]
#  [329 352]
#  [336 352]
#  [336 373]]
# [[329 352]
#  [329 336]
#  [336 336]
#  [336 352]]
# [[329 336]
#  [329 321]
#  [336 321]
#  [336 336]]
# [[329 321]
#  [329 308]
#  [336 308]
#  [336 321]]
# [[336 390]
#  [336 377]
#  [347 377]
#  [347 390]]
# [[336 377]
#  [336 373]
#  [347 373]
#  [347 377]]
# [[336 373]
#  [336 352]
#  [347 352]
#  [347 373]]
# [[336 352]
#  [336 336]
#  [347 336]
#  [347 352]]
# [[336 336]
#  [336 321]
#  [347 321]
#  [347 336]]
# [[336 321]
#  [336 308]
#  [347 308]
#  [347 321]]
# [[347 390]
#  [347 377]
#  [362 377]
#  [362 390]]
# [[347 377]
#  [347 373]
#  [362 373]
#  [362 377]]
# [[347 373]
#  [347 352]
#  [362 352]
#  [362 373]]
# [[347 352]
#  [347 336]
#  [362 336]
#  [362 352]]
# [[347 336]
#  [347 321]
#  [362 321]
#  [362 336]]
# [[347 321]
#  [347 308]
# ...

# %%
print(x)
print(x[0])
# Out:
# [[1, 2, 3]]
# [1, 2, 3]
